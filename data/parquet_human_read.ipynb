# %%
import pyarrow.parquet as pq

# %%
# Read a single file
table = pq.read_table('cache/raw_data.parquet')
df = table.to_pandas()

df.head()
# Out:
# Ticker             GLD                                                \
# Price             Open        High         Low       Close    Volume
# Date
# 2010-01-04  109.820000  110.139999  109.309998  109.800003  16224100
# 2010-01-05  109.879997  110.389999  109.260002  109.699997  14213100
# 2010-01-06  110.709999  111.769997  110.410004  111.510002  24981900
# 2010-01-07  111.070000  111.290001  110.620003  110.820000  13609800
# 2010-01-08  111.519997  111.580002  110.260002  111.370003  15894600
#
# Ticker              UNG                                                 ...  \
# Price              Open         High          Low        Close  Volume  ...
# Date                                                                    ...
# 2010-01-04  1351.680054  1364.479980  1331.199951  1361.920044  185932  ...
# 2010-01-05  1349.119995  1352.959961  1304.319946  1320.959961  179730  ...
# 2010-01-06  1355.520020  1401.599976  1350.400024  1386.239990  317573  ...
# ...

# %%
df.shape
# Out:
# (4023, 60)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 4023 entries, 2010-01-04 to 2025-12-30
# Data columns (total 60 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   (GLD, Open)    4023 non-null   float64
#  1   (GLD, High)    4023 non-null   float64
#  2   (GLD, Low)     4023 non-null   float64
#  3   (GLD, Close)   4023 non-null   float64
#  4   (GLD, Volume)  4023 non-null   int64
#  5   (UNG, Open)    4023 non-null   float64
#  6   (UNG, High)    4023 non-null   float64
#  7   (UNG, Low)     4023 non-null   float64
#  8   (UNG, Close)   4023 non-null   float64
#  9   (UNG, Volume)  4023 non-null   int64
#  10  (EEM, Open)    4023 non-null   float64
#  11  (EEM, High)    4023 non-null   float64
#  12  (EEM, Low)     4023 non-null   float64
#  13  (EEM, Close)   4023 non-null   float64
#  14  (EEM, Volume)  4023 non-null   int64
#  15  (AGG, Open)    4023 non-null   float64
#  16  (AGG, High)    4023 non-null   float64
# ...
